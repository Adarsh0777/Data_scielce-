# %%
import pandas as pd 
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.DataFrame({"Size":["s","m","l","xxl","xxxl","s","s","m","l","xl","m","xxxl"]})

# %%
df.head(2)
# Out:
#   Size
# 0    s
# 1    m

# %%
ord_data=[["s","m","l","xl","xxl","xxxl"]]

# %%
oe=OrdinalEncoder(categories=ord_data)
oe.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl', 'xxl', 'xxxl']])

# %%
df["Size_en"]=oe.transform(df[["Size"]])

# %%
df
# Out:
#     Size  Size_en
# 0      s      0.0
# 1      m      1.0
# 2      l      2.0
# 3    xxl      4.0
# 4   xxxl      5.0
# 5      s      0.0
# 6      s      0.0
# 7      m      1.0
# 8      l      2.0
# 9     xl      3.0
# 10     m      1.0
# 11  xxxl      5.0

# %%
ord={"s":0,"m":1,"l":2,"xl":3,"xxl":4,"xxxl":5}

# %%
df["Size_enn"]=df["Size"].map(ord)

# %%
df
# Out:
#     Size  Size_en  Size_enn
# 0      s      0.0         0
# 1      m      1.0         1
# 2      l      2.0         2
# 3    xxl      4.0         4
# 4   xxxl      5.0         5
# 5      s      0.0         0
# 6      s      0.0         0
# 7      m      1.0         1
# 8      l      2.0         2
# 9     xl      3.0         3
# 10     m      1.0         1
# 11  xxxl      5.0         5

# %%
dataset=pd.read_csv("Electric_Vehicle_Population_Data.csv")
dataset.head(2)
# Out:
#    VIN (1-10)  County     City State  Postal Code  Model Year   Make    Model  \
# 0  5YJ3E1EBXK    King  Seattle    WA      98178.0      2019.0  TESLA  MODEL 3
# 1  5YJYGDEE3L  Kitsap  Poulsbo    WA      98370.0      2020.0  TESLA  MODEL Y
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
# 1  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           220.0
# 1           Clean Alternative Fuel Vehicle Eligible           291.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  37.0       477309682
# 1        0.0                  23.0       109705683
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-122.23825 47.49461)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
#
# ...

# %%
dataset["Electric Vehicle Type"].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
ord_data1=[["Battery Electric Vehicle (BEV)","Plug-in Hybrid Electric Vehicle (PHEV)"]]

# %%
ord2=OrdinalEncoder(categories=ord_data1)

# %%
dataset["Electric Vehicle Type"]=ord2.fit_transform(dataset[["Electric Vehicle Type"]])

# %%
dataset.head(10)
# Out:
#    VIN (1-10)     County        City State  Postal Code  Model Year     Make  \
# 0  5YJ3E1EBXK       King     Seattle    WA      98178.0      2019.0    TESLA
# 1  5YJYGDEE3L     Kitsap     Poulsbo    WA      98370.0      2020.0    TESLA
# 2  KM8KRDAF5P     Kitsap      Olalla    WA      98359.0      2023.0  HYUNDAI
# 3  5UXTA6C0XM     Kitsap     Seabeck    WA      98380.0      2021.0      BMW
# 4  JTMAB3FV7P   Thurston     Rainier    WA      98576.0      2023.0   TOYOTA
# 5  5YJSA1DN0C   Thurston     Olympia    WA      98502.0      2012.0    TESLA
# 6  WBY1Z6C30H       King    Bellevue    WA      98004.0      2017.0      BMW
# 7  3MW5P9J0XN  Snohomish  Marysville    WA      98271.0      2022.0      BMW
# 8  5YJ3E1EA6J       King    Kirkland    WA      98034.0      2018.0    TESLA
# 9  5YJ3E1EA2J       King     Redmond    WA      98052.0      2018.0    TESLA
#
#         Model  Electric Vehicle Type  \
# 0     MODEL 3                    0.0
# 1     MODEL Y                    0.0
# ...
