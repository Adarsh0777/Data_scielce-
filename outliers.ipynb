# %%
import pandas as pd 
from sklearn.preprocessing import OrdinalEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
dataset.head(3)
# Out:
#    VIN (1-10)  County     City State  Postal Code  Model Year     Make  \
# 0  5YJ3E1EBXK    King  Seattle    WA      98178.0      2019.0    TESLA
# 1  5YJYGDEE3L  Kitsap  Poulsbo    WA      98370.0      2020.0    TESLA
# 2  KM8KRDAF5P  Kitsap   Olalla    WA      98359.0      2023.0  HYUNDAI
#
#      Model           Electric Vehicle Type  \
# 0  MODEL 3  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  IONIQ 5  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible           220.0
# 1            Clean Alternative Fuel Vehicle Eligible           291.0
# 2  Eligibility unknown as battery range has not b...             0.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  37.0       477309682
# 1        0.0                  23.0       109705683
# 2        0.0                  26.0       230390492
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235692 entries, 0 to 235691
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         235682 non-null  object
#  1   County                                             235689 non-null  object
#  2   City                                               235689 non-null  object
#  3   State                                              235692 non-null  object
#  4   Postal Code                                        235674 non-null  float64
#  5   Model Year                                         235681 non-null  float64
#  6   Make                                               235676 non-null  object
#  7   Model                                              235692 non-null  object
# ...

# %%
dataset.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  235674.000000  235681.000000   235653.000000  235656.000000
# mean    98177.647360    2021.406647       47.134422     787.268328
# std      2524.297292       2.991886       84.863264    7177.668305
# min      1731.000000    2000.000000        0.000000       0.000000
# 25%     98052.000000    2020.000000        0.000000       0.000000
# 50%     98126.000000    2023.000000        0.000000       0.000000
# 75%     98374.000000    2024.000000       38.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         235198.000000    2.356920e+05       2.356890e+05
# mean              28.879519    2.353127e+08       5.298066e+10
# std               14.904644    6.799098e+07       1.521066e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Electric Range",data=dataset)
plt.show()

# %%
#outlier method iqr remover

# %%
dataset.shape
# Out:
# (235692, 17)

# %%
q1=dataset["Electric Range"].quantile(0.25)
q3=dataset["Electric Range"].quantile(0.75)
q1,q3
# Out:
# (0.0, 38.0)

# %%
iqr=q3-q1
iqr
# Out:
# 38.0

# %%
min_range=q1-(1.5*iqr)
max_range=q3+(1.5*iqr)
min_range,max_range
# Out:
# (-57.0, 95.0)

# %%
new_dataset=dataset[dataset["Electric Range"]<=max_range]
new_dataset
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0      2023.0
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0      2021.0
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0      2023.0
# 6       WBY1Z6C30H       King      Bellevue    WA      98004.0      2017.0
# 7       3MW5P9J0XN  Snohomish    Marysville    WA      98271.0      2022.0
# ...            ...        ...           ...   ...          ...         ...
# 235686  7SAYGDEE2P       King       Seattle    WA      98109.0      2023.0
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0      2024.0
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0      2015.0
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0      2023.0
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0      2023.0
#
# ...

# %%
new_dataset.shape
# Out:
# (195999, 17)

# %%
sns.boxplot(x="Electric Range",data=new_dataset)
plt.show()

# %%
#z score method

# %%
sns.boxplot(x="Postal Code",data=dataset)
plt.show()

# %%
sns.distplot(dataset["Postal Code"])
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_14284\3196433705.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Postal Code"])

# %%
min_range1=dataset["Postal Code"].mean()-(3*dataset["Postal Code"].std())
max_range1=dataset["Postal Code"].mean()+(3*dataset["Postal Code"].std())
min_range1,max_range1
# Out:
# (90604.75548317612, 105750.53923749735)

# %%
new_dataset2=dataset[dataset["Postal Code"]>=min_range1]
new_dataset2
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EBXK       King       Seattle    WA      98178.0      2019.0
# 1       5YJYGDEE3L     Kitsap       Poulsbo    WA      98370.0      2020.0
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0      2023.0
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0      2021.0
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0      2023.0
# ...            ...        ...           ...   ...          ...         ...
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0      2024.0
# 235688  5YJSA1E28J  Snohomish      Stanwood    WA      98292.0      2018.0
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0      2015.0
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0      2023.0
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0      2023.0
#
# ...

# %%
sns.boxplot(x="Postal Code",data=new_dataset2)
plt.show()

# %%
z_score=(dataset["Postal Code"]-dataset["Postal Code"].mean())/(dataset["Postal Code"].std())
z_score
# Out:
# 0         0.000140
# 1         0.076200
# 2         0.071843
# 3         0.080162
# 4         0.157807
#             ...
# 235687    0.090858
# 235688    0.045301
# 235689   -0.049775
# 235690    0.031832
# 235691   -0.059679
# Name: Postal Code, Length: 235692, dtype: float64

# %%
dataset["z_score"]=z_score
dataset[dataset["z_score"]<3]
dataset
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EBXK       King       Seattle    WA      98178.0      2019.0
# 1       5YJYGDEE3L     Kitsap       Poulsbo    WA      98370.0      2020.0
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0      2023.0
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0      2021.0
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0      2023.0
# ...            ...        ...           ...   ...          ...         ...
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0      2024.0
# 235688  5YJSA1E28J  Snohomish      Stanwood    WA      98292.0      2018.0
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0      2015.0
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0      2023.0
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0      2023.0
#
# ...
